# %%
import json
import pylab as pl
import random
import numpy as np
import cv2 # pip install opencv-python
import anno_func
# %matplotlib inline

# %%
datadir = "D:\\TT100K\data"

filedir = datadir + "\\annotations.json"
ids = open(datadir + "\\test\ids.txt").read().splitlines()

annos = json.loads(open(filedir).read())

# %%
imgid = random.sample(ids, 1)[0]
print(imgid)

imgdata = anno_func.load_img(annos, datadir, imgid)
imgdata_draw = anno_func.draw_all(annos, datadir, imgid, imgdata)
pl.figure(figsize=(20,20))
pl.imshow(imgdata_draw)
# Out:
# 88472
# ((223.72933959960938, 595.5762939453125), (40.31330490112305, 69.52459716796875), 171.16732788085938)
# ((1855.74853515625, 851.5645751953125), (26.59403419494629, 29.689603805541992), 162.44680786132812)
# ((2022.416259765625, 866.7242431640625), (20.59897804260254, 30.02803611755371), 162.93115234375)
